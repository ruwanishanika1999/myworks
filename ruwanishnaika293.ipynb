# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/project/")
os.getcwd()

img = image.load_img("Training/1/ra.1.jpeg")

plt.imshow(img)

cv2.imread("Training/1/ra.1.jpeg").shape

train = ImageDataGenerator(rescale = 1/255)

validation = ImageDataGenerator(rescale = 1/255)

train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')

train_dataset.class_indices

train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])



model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)


validation_dataset.class_indices

dir_path = 'Testing/'

for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()

  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'Ra' in Sinhala")
  else:
    print("This is Letter 'Ta' in Sinhala")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 5s 976ms/step - loss: 6.6656 - accuracy: 0.4667 - val_loss: 1.0487 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7703 - accuracy: 0.4667 - val_loss: 0.7007 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7258 - accuracy: 0.4667 - val_loss: 0.6849 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6877 - accuracy: 0.6000 - val_loss: 0.6688 - val_accuracy: 0.8300
# Epoch 5/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7285 - accuracy: 0.3333 - val_loss: 0.6854 - val_accuracy: 0.5000
# Epoch 6/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6944 - accuracy: 0.6667 - val_loss: 0.7251 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.1593 - accuracy: 0.6667 - val_loss: 1.0064 - val_accuracy: 0.5000
# Epoch 8/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7604 - accuracy: 0.5385 - val_loss: 0.7500 - val_accuracy: 0.5000
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7745 - accuracy: 0.6667 - val_loss: 0.6482 - val_accuracy: 0.7900
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6576 - accuracy: 0.6667 - val_loss: 0.5639 - val_accuracy: 0.7800
# Epoch 11/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5580 - accuracy: 0.7333 - val_loss: 0.5754 - val_accuracy: 0.6600
# Epoch 12/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7531 - accuracy: 0.6667 - val_loss: 0.5807 - val_accuracy: 0.7500
# Epoch 13/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.5089 - accuracy: 0.8667 - val_loss: 0.4849 - val_accuracy: 0.7400
# Epoch 14/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2871 - accuracy: 1.0000 - val_loss: 0.3898 - val_accuracy: 0.8300
# Epoch 15/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5603 - accuracy: 0.6667 - val_loss: 0.5011 - val_accuracy: 0.7600
# Epoch 16/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7624 - accuracy: 0.8000 - val_loss: 0.4007 - val_accuracy: 0.8300
# Epoch 17/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.3131 - accuracy: 0.9333 - val_loss: 0.3337 - val_accuracy: 0.8800
# Epoch 18/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3266 - accuracy: 0.9333 - val_loss: 2.7473 - val_accuracy: 0.5000
# Epoch 19/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5604 - accuracy: 0.8667 - val_loss: 0.4835 - val_accuracy: 0.8000
# Epoch 20/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2737 - accuracy: 0.9333 - val_loss: 0.2858 - val_accuracy: 0.8600
# Epoch 21/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1694 - accuracy: 0.9333 - val_loss: 0.1735 - val_accuracy: 0.9300
# Epoch 22/30
# 5/5 [==============================] - 4s 959ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.8400
# Epoch 23/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1052 - accuracy: 0.9333 - val_loss: 0.2349 - val_accuracy: 0.9000
# Epoch 24/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1844 - accuracy: 0.8667 - val_loss: 0.1837 - val_accuracy: 0.9200
# Epoch 25/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.1943 - accuracy: 0.9333 - val_loss: 0.1899 - val_accuracy: 0.9100
# Epoch 26/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3888 - accuracy: 0.8667 - val_loss: 0.2975 - val_accuracy: 0.9700
# Epoch 27/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9400
# Epoch 28/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9600
# Epoch 29/30
# 5/5 [==============================] - 4s 902ms/step - loss: 0.5530 - accuracy: 0.8000 - val_loss: 0.0844 - val_accuracy: 0.9600
# Epoch 30/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9700
# 1/1 [==============================] - 0s 107ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 32ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 49ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 56ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 62ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 62ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 70ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 62ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ra' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'Ta' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ta' in Sinhala
